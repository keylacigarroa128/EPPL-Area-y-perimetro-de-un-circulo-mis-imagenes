# %% [markdown]
# <a href="https://colab.research.google.com/github/keylacigarroa128/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes/blob/main/el_profe_circulo_Keyla_Cigarroa_0033.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Keyla Paola Cigarroa Palacios NL = 12  Fecha = 25/Mar/2026 👾
# ---
# # Calcular Area y Perimetro de un Circulo
# ---
# ![Logo de Markdown](https://raw.githubusercontent.com/keylacigarroa128/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes/refs/heads/main/circulo_area_perimetro.PNG)
#
# ---
# ## formula para calcular area
# $A=\pi*r^2$
#
# ---
# ## Formula para calcular perimetro
# $P=2*\pi*r$
#
# ---
# ## Datos de entrada
# $r$  ?
#
# ---
# ## Diagrama de flujo en Lucidchart
# ![Logo de Markdown](https://raw.githubusercontent.com/keylacigarroa128/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes/refs/heads/main/DF%20Area%20Perimetro%20Circulo.png)

# %%
# Calcular area y perimetro
# variables A, P, r
# Formulas A = pi*r^2 y P = 2 * pi * r
# Calcular el valor de r
import math
print("calcular el area y perimetro de un circulo")
r = float(input("ingrese el valor del radio: "))
A = math.pi * r**2
P = 2 * math.pi * r
print("el area del circulo es: ", A)
print("el perimetro del circulo es: ", P)
print("keyla Paola Cigarroa Palacios NL = 12")
# Out:
# calcular el area y perimetro de un circulo
# ingrese el valor del radio: 5
# el area del circulo es:  78.53981633974483
# el perimetro del circulo es:  31.41592653589793
# keyla Paola Cigarroa Palacios NL = 12

# %% [markdown]
# # Relacion entre codigo y DF en tldraw
# ![Logo de Markdown](https://raw.githubusercontent.com/keylacigarroa128/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes/refs/heads/main/tldraw%20DF%20y%20codigo.png)
